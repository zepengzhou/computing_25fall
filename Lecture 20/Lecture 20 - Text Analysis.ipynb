# %% [markdown]
# # <span style="color:darkblue"> Lecture 20: Text Analysis </span>
#
# <font size = "5">
#
# Intro text analysis
#
# https://www.youtube.com/watch?v=IRKDrrzh4dE

# %% [markdown]
# # <span style="color:darkblue"> I. Setup Working Environment </span>

# %%
#pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from faiss-cpu) (2.3.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.12.0-cp312-cp312-macosx_14_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 8.9 MB/s  0:00:00m eta 0:00:01
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
#!pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from seaborn) (2.3.4)
# Requirement already satisfied: pandas>=1.2 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/tf312/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
# Import SK-Learn library for machine learning functions
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS 
from sklearn.decomposition import TruncatedSVD
from sklearn.model_selection import train_test_split



# Import standard data analysis packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import Kmenas
from sklearn.cluster import MiniBatchKMeans

import faiss

# %% [markdown]
# # <span style="color:darkblue"> II. Data </span>
#
# <font size = "5">
#
# We will analyze a dataset on Amazon Reviews
#
# https://www.kaggle.com/datasets/yasserh/amazon-product-reviews-dataset/data

# %%
data = pd.read_csv("data_raw/amazon_reviews.csv")

len(data)
# Out:
# 1597

# %% [markdown]
# <font size = "5">
#
# Check features

# %%
data.columns
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'colors', 'dateAdded',
#        'dateUpdated', 'dimension', 'ean', 'keys', 'manufacturer',
#        'manufacturerNumber', 'name', 'prices', 'reviews.date',
#        'reviews.doRecommend', 'reviews.numHelpful', 'reviews.rating',
#        'reviews.sourceURLs', 'reviews.text', 'reviews.title',
#        'reviews.userCity', 'reviews.userProvince', 'reviews.username', 'sizes',
#        'upc', 'weight'],
#       dtype='object')

# %% [markdown]
# <font size = "5">
#
# Check text

# %%
reviews = data["reviews.text"]

# %% [markdown]
# <font size = "5">
#
# Check rating

# %%
plt.hist(x = data["reviews.rating"])
# Out:
# (array([ 42.,   0.,  34.,   0.,   0., 124.,   0., 236.,   0., 741.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <font size = "5">
#
# Filter non-missing ratings data
#
# - 26% missing data!
# - Could generate selection bias in reviews

# %%
# Check for missing values
# A lot of reviews are missing review data
missing_values = data["reviews.rating"].isnull().sum()
percent_missing = missing_values /len(data)
print(percent_missing)

# Extract non-missing data
data_nonmissing = data[data["reviews.rating"].notnull()]
# Out:
# 0.2629931120851597

# %% [markdown]
# # <span style="color:darkblue"> III. Bag of Words </span>

# %% [markdown]
# <font size = "5">
#
# Stop words
#
# - Commonly used words
# - Available for different languages

# %%
# First ten English stop words
list(ENGLISH_STOP_WORDS)[0:10]
# Out:
# ['whatever',
#  'cry',
#  'un',
#  'another',
#  'those',
#  'if',
#  'whereby',
#  'last',
#  'will',
#  'indeed']

# %% [markdown]
# <font size = "5">
#
# Create custom stop words

# %%
# Here we added Python to the list of stop words
custom_stop_words = list(ENGLISH_STOP_WORDS) + ["Python"]

# You can also create your own list
# custom_stop_words = ["and","or","how"]

# %% [markdown]
# <font size = "5">
#
# Count vectorizer
#
# - Check for distinct words across all reviews
# - Remove any stop words
# - ```min_df``` is used to filter out words depending <br>
# on how often they occur. For example, ```min_df=3``` <br>
# only keeps words if they are mentioned at least 3 times

# %%
word_model = CountVectorizer(min_df=1,
                       stop_words=custom_stop_words)
word_model.fit(reviews)
# Out:
# /opt/anaconda3/envs/tf312/lib/python3.12/site-packages/sklearn/feature_extraction/text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['python'] not in stop_words.
#   warnings.warn(
# CountVectorizer(stop_words=['whatever', 'cry', 'un', 'another', 'those', 'if',
#                             'whereby', 'last', 'will', 'indeed', 'side', 'call',
#                             'amongst', 'mostly', 'which', 'any', 'never',
#                             'nothing', 'had', 'whereas', 'these', 'find',
#                             'though', 'do', 'much', 'and', 'me', 'elsewhere',
#                             'thereafter', 'wherever', ...])

# %% [markdown]
# <font size = "5">
#
# Check Vocabulary
#
# - Check in VS-Code Data Viewer
# - You can use preliminary findings to decide whether <br>
# to add more stop words

# %%
# Extract words in vocabulary and frequency
vocabulary = word_model.vocabulary_

# Convert to dataframew
frequency_words  = pd.DataFrame(vocabulary.items(),
                                columns=['Word', 'Frequency'])
                                
# Display sorted dataset                                
frequency_words.sort_values(by = "Frequency",ascending=False)
# Out:
#          Word  Frequency
# 4309     zumi       6194
# 4474  zooming       6193
# 4856     zoom       6192
# 5496  zombies       6191
# 2692    zippy       6190
# ...       ...        ...
# 1449       07          4
# 3398       04          3
# 484      000s          2
# 494       000          1
# 112        00          0
#
# [6195 rows x 2 columns]

# %% [markdown]
# <font size = "5">
#
# Create a dataset counting which words are used <br>
# per review
#
# - Each row is a different review
# - Each column is a ${0,1}$ indicator on whether that <br>
# word was mentioned
# - Huge matrix!!

# %%
# Create X matrix
X = word_model.transform(reviews)

# Check dimension of X matrix
np.shape(X)

X_dataframe = pd.DataFrame(X)

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# Create a bag of words for the column "review.title".
#
# - What are the most common words?

# %%
# Write your own code

# %% [markdown]
# # <span style="color:darkblue"> IV. Sentiment Analysis </span>
#
# <font size = "5">
# Sentiment analsys uses words to predict user ratings. <br>
#
#
# - In this case we have ratings labels
# - We'll use the data with nonmissing labels

# %%
# Write your own code

text = data_nonmissing["reviews.text"]
y    = data_nonmissing["reviews.rating"]

text_train, text_test, y_train, y_test = train_test_split(text, y,
                                                    random_state=0)

# %% [markdown]
# <font size = "5">
#
# Extract vectorized X

# %%
# Create X matrix
word_model_train = CountVectorizer(min_df=1,
                       stop_words=custom_stop_words)
word_model_train.fit(text_train)
X_train = word_model.transform(text_train)

# Check dimension of X matrix
np.shape(X)
# Out:
# /Users/asanc31/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['python'] not in stop_words.
#   warnings.warn(
# (1597, 6195)

# %% [markdown]
# <font size = "5">
#
# We can compress the data using <br>
# truncated singular value decomposition (SVD)
#
# - This is an alternative to PCA that is better suited <br>
# for sparse, binary data like text

# %%
svd = TruncatedSVD(n_components=3,random_state=42);
svd.fit(X_train)
X_svd_train = svd.transform(X_train)
np.shape(X_svd_train)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# (882, 3)

# %%
# Hue is used to color
ax = sns.scatterplot(x = X_svd_train[:,0],
                     y = y_train)
ax.set(xlabel='First Principal Component',
       ylabel='Second Principal Component')
# Out:
# [Text(0.5, 0, 'First Principal Component'),
#  Text(0, 0.5, 'Second Principal Component')]

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# Create a machine learning pipeline
#
# - Run a support vector machine regression to predict user ratings
# - What is the out-of-sample performance on the test data?
# - Use your data to predict reviews that were missing
# - How does the distribution of missing to non-missing reviews compare?

# %%
# Write your own code

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - What happens if you change the minimum frequency of words <br>
# and/or change the number of components?

# %%
# Write your own code
